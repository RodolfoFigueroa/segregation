# %%
from pathlib import Path

from segregation.preprocessing import load_survey

# %%
df_survey = load_survey(
    data_path=Path("./data"),
    met_zone_codes=[1001, 1002],
    linking_cols=["Sexo", "Edad", "Nivel", "SeguroIMSS", "SeguroPriv", "ConexionInt"],
    q=5,
)

# %%
df_survey
# Out:
#      Sexo    Edad       Nivel SeguroIMSS  SeguroPriv ConexionInt Ingreso  \
# 0       m  p65mas    primaria    no_imss  no_privado    internet       5
# 1       f  p65mas    primaria    no_imss  no_privado    internet       1
# 2       m  p15_64   posbasica    no_imss  no_privado    internet       4
# 3       m  p15_64   posbasica    no_imss  no_privado    internet       3
# 4       f  p15_64   posbasica    no_imss  no_privado    internet       1
# ...   ...     ...         ...        ...         ...         ...     ...
# 4040    f  p15_64  secundaria    no_imss  no_privado    internet       1
# 4041    m  p15_64   posbasica       imss  no_privado    internet       4
# 4042    f  p15_64  secundaria    no_imss  no_privado    internet       1
# 4043    f  p15_64   posbasica    no_imss  no_privado    internet       3
# 4044    m  p15_64   posbasica    no_imss  no_privado    internet       3
#
#       Ingreso_orig
# 0         38655.73
# 1          1622.95
# 2         23606.55
# ...
